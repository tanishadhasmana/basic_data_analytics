# %%
import pandas as pd

# %%
df = pd.read_excel("Country-Code.xlsx")

# %%
df.isnull().sum()
# Out:
# Country Code    0
# Country         0
# dtype: int64

# %%
df.head()
# Out:
#    Country Code    Country
# 0             1      India
# 1            14  Australia
# 2            30     Brazil
# 3            37     Canada
# 4            94  Indonesia

# %%
df['Country'].value_counts()
# Out:
# Country
# India             1
# Australia         1
# Brazil            1
# Canada            1
# Indonesia         1
# New Zealand       1
# Phillipines       1
# Qatar             1
# Singapore         1
# South Africa      1
# Sri Lanka         1
# Turkey            1
# UAE               1
# United Kingdom    1
# United States     1
# Name: count, dtype: int64

# %%
df1 = pd.read_csv("/content/zomato.csv" , encoding ="latin1")
df1
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
# ...

# %%
df1[df1['City']=='Makati City']['Restaurant Name']
# Out:
# 0    Le Petit Souffle
# 1    Izakaya Kikufuji
# Name: Restaurant Name, dtype: object

# %%
df1[df1['City']=='Dehradun']['Restaurant Name']
# Out:
# 845    The Punjabi Essence Restaurant
# 846               Tirupati Restaurant
# 847                           Anandam
# 848             Town Table Restaurant
# 849            Kalsang Friends Corner
# 850              The Great Indian Pub
# 851              BMG - All Day Dining
# 852                      Punjab Grill
# 853                           TBistro
# 854               Y Cafe & Restaurant
# 855                Eddie's Patisserie
# 856                   First Gear Cafe
# 857                     Dunkin Donuts
# 858                       Doon Darbar
# 859                        Razzmatazz
# 860                   Barbeque Nation
# 861           Black Pepper Restaurant
# 862                     Cafe Marigold
# 863                         Jalapenos
# 864                  Kalsang AMA Cafe
# Name: Restaurant Name, dtype: object

# %%
df1[(df1['City']=='Dehradun') & (df1['Rating text'] == 'Good')]
# Out:
#      Restaurant ID                 Restaurant Name  Country Code      City  \
# 845        3500012  The Punjabi Essence Restaurant             1  Dehradun
# 846        3500007             Tirupati Restaurant             1  Dehradun
# 847        3500017                         Anandam             1  Dehradun
# 848        3500018           Town Table Restaurant             1  Dehradun
# 853        3500059                         TBistro             1  Dehradun
# 856        3500365                 First Gear Cafe             1  Dehradun
# 857        3500013                   Dunkin Donuts             1  Dehradun
# 858        3500024                     Doon Darbar             1  Dehradun
# 859        3500488                      Razzmatazz             1  Dehradun
#
#                                                Address              Locality  \
# 845  27 B, Near Premier Plaza, Rajpur Road, Chukkuw...            Chukkuwala
# ...

# %%
df1[df1['Rating text']== 'Good']['City'].value_counts()
# Out:
# City
# New Delhi         1128
# Gurgaon            257
# Noida              173
# Faridabad           22
# Waterloo            19
#                   ...
# Orlando              1
# Phillip Island       1
# Rest of Hawaii       1
# Abu Dhabi            1
# Santa Rosa           1
# Name: count, Length: 102, dtype: int64

# %%
df1[df1['Rating text']== 'Good']['City'].value_counts().head(5).plot(kind = 'bar')
# Out:
# <Axes: xlabel='City'>

# %%
df1['Rating text'].nunique()
# Out:
# 6

# %%
df1['Rating text'].unique()
# Out:
# array(['Excellent', 'Very Good', 'Good', 'Average', 'Not rated', 'Poor'],
#       dtype=object)
