# %%
import pandas as pd
data = {"name": ['ram','shyam','radha','sita'],
        "class": [2,5,6,8], "sec": ['A','B','C','D']}
df=pd.DataFrame(data,index =[0,1,2,3])
df
# Out:
#     name  class sec
# 0    ram      2   A
# 1  shyam      5   B
# 2  radha      6   C
# 3   sita      8   D
